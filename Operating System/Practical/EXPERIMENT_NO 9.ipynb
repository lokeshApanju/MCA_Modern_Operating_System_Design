# %%
def fifo_page_replacement(pages, capacity):
    frames = []
    page_faults = 0
    for page in pages:
        if page not in frames:
            page_faults += 1
            if len(frames) == capacity:
                frames.pop(0)   # Remove oldest page
            frames.append(page)
        print(f"Page: {page} -> Frames: {frames}")

    print("Total Page Faults (FIFO):", page_faults)
# Example
pages = [7, 0, 1, 2, 0, 3, 2, 4]
capacity = 4
fifo_page_replacement(pages, capacity)
# Out:
# Page: 7 -> Frames: [7]
# Page: 0 -> Frames: [7, 0]
# Page: 1 -> Frames: [7, 0, 1]
# Page: 2 -> Frames: [7, 0, 1, 2]
# Page: 0 -> Frames: [7, 0, 1, 2]
# Page: 3 -> Frames: [0, 1, 2, 3]
# Page: 2 -> Frames: [0, 1, 2, 3]
# Page: 4 -> Frames: [1, 2, 3, 4]
# Total Page Faults (FIFO): 6

# %%
def lru_page_replacement(pages, capacity):
    frames = []
    page_faults = 0
    for page in pages:
        if page not in frames:
            page_faults += 1
            if len(frames) == capacity:
                frames.pop(0)   # Remove LRU page
        else:
            frames.remove(page)  # Move page to recent position

        frames.append(page)
        print(f"Page: {page} -> Frames: {frames}")

    print("Total Page Faults (LRU):", page_faults)

# Example
pages = [7, 0, 1, 2, 0, 3, 2, 4]
capacity = 4
lru_page_replacement(pages, capacity)
# Out:
# Page: 7 -> Frames: [7]
# Page: 0 -> Frames: [7, 0]
# Page: 1 -> Frames: [7, 0, 1]
# Page: 2 -> Frames: [7, 0, 1, 2]
# Page: 0 -> Frames: [7, 1, 2, 0]
# Page: 3 -> Frames: [1, 2, 0, 3]
# Page: 2 -> Frames: [1, 0, 3, 2]
# Page: 4 -> Frames: [0, 3, 2, 4]
# Total Page Faults (LRU): 6
