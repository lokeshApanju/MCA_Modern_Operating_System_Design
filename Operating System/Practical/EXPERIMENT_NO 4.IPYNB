# %%
import psutil
processes = []
for proc in psutil.process_iter(['pid', 'name', 'username']):
    try:
        info = proc.info
        info['cpu_percent'] = proc.cpu_percent(interval=0.1)
        processes.append(info)
    except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
        pass

processes = sorted(processes, key=lambda x: x['cpu_percent'], reverse=True)
for proc in processes[:5]:
    print(f"Process Name: {proc['name']}, PID: {proc['pid']}, CPU Usage: {proc['cpu_percent']}%")
# Out:
# Process Name: System Idle Process, PID: 0, CPU Usage: 931.8%
# Process Name: dwm.exe, PID: 22296, CPU Usage: 69.9%
# Process Name: brave.exe, PID: 16816, CPU Usage: 31.1%
# Process Name: Code.exe, PID: 4588, CPU Usage: 31.0%
# Process Name: svchost.exe, PID: 1512, CPU Usage: 29.0%
